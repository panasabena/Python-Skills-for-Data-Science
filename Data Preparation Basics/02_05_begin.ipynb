# %% [markdown]
# # Chapter 2 - Data Preparation Basics
# ## Segment 5 - Grouping and data aggregation

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### Grouping data by column index

# %%
## Abrimos primero el dataset y lo guardamos en una variable(que esta en formato csv)
address = r'C:\Users\fsabena\OneDrive - MicroStrategy, Inc\Capacitaciones y Cursos\Python for Data Science (Linkedin Learning)\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\mtcars.csv'
## Leemos el dataset
cars = pd.read_csv(address)
## Le asignamos nombre a las columnas de los dataset
cars.columns = ['cars_names', 'mpg', 'cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
cars.head(5)
# Out:
#           cars_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars_group = cars.groupby(cars['cyl'])
cars_group.mean()
# Out:
#            mpg        disp          hp      drat        wt       qsec  \
# cyl
# 4    26.663636  105.136364   82.636364  4.070909  2.285727  19.137273
# 6    19.742857  183.314286  122.285714  3.585714  3.117143  17.977143
# 8    15.100000  353.100000  209.214286  3.229286  3.999214  16.772143
#
#            vs        am      gear      carb
# cyl
# 4    0.909091  0.727273  4.090909  1.545455
# 6    0.571429  0.428571  3.857143  3.428571
# 8    0.000000  0.142857  3.285714  3.500000

# %%
## Using the mtcars dataset, group the data by the transmission type "am".
## Which transmission type has the highest mean miles/(US) gallon "mpg" and 
## its corresponding value?
cars_group_am = cars.groupby(cars['am'])
cars_group_am.mean()
# Out:
#           mpg       cyl        disp          hp      drat        wt  \
# am
# 0   17.147368  6.947368  290.378947  160.263158  3.286316  3.768895
# 1   24.392308  5.076923  143.530769  126.846154  4.050000  2.411000
#
#          qsec        vs      gear      carb
# am
# 0   18.183158  0.368421  3.210526  2.736842
# 1   17.360000  0.538462  4.384615  2.923077

# %%
cars_subset=cars[['mpg', 'disp', 'hp', 'wt']]
cars_subset
# Out:
#      mpg   disp   hp     wt
# 0   21.0  160.0  110  2.620
# 1   21.0  160.0  110  2.875
# 2   22.8  108.0   93  2.320
# 3   21.4  258.0  110  3.215
# 4   18.7  360.0  175  3.440
# 5   18.1  225.0  105  3.460
# 6   14.3  360.0  245  3.570
# 7   24.4  146.7   62  3.190
# 8   22.8  140.8   95  3.150
# 9   19.2  167.6  123  3.440
# 10  17.8  167.6  123  3.440
# 11  16.4  275.8  180  4.070
# 12  17.3  275.8  180  3.730
# 13  15.2  275.8  180  3.780
# 14  10.4  472.0  205  5.250
# 15  10.4  460.0  215  5.424
# 16  14.7  440.0  230  5.345
# 17  32.4   78.7   66  2.200
# 18  30.4   75.7   52  1.615
# 19  33.9   71.1   65  1.835
# 20  21.5  120.1   97  2.465
# 21  15.5  318.0  150  3.520
# 22  15.2  304.0  150  3.435
# 23  13.3  350.0  245  3.840
# 24  19.2  400.0  175  3.845
# 25  27.3   79.0   66  1.935
# 26  26.0  120.3   91  2.140
# 27  30.4   95.1  113  1.513
# 28  15.8  351.0  264  3.170
# 29  19.7  145.0  175  2.770
# 30  15.0  301.0  335  3.570
# 31  21.4  121.0  109  2.780

# %%
items_adress = r'C:\Users\fsabena\OneDrive - MicroStrategy, Inc\Capacitaciones y Cursos\Python for Data Science (Linkedin Learning)\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\Superstore-Sales.csv'
items = pd.read_csv(items_adress)
items.head(2)
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3  10/13/2010            Low               6    261.54
# 1      49       293   10/1/2012           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin   Ship Date
# ...

# %%
groupbyitem=items.groupby(items['item_type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'item_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-c9ed423d9377> in <module>
# ...
